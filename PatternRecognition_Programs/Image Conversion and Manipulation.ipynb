# %% [markdown]
# import libraries

# %%
import matplotlib.pyplot as plt
import numpy as np
from skimage import transform

# %%
# Resmi oku
img1 = plt.imread('cat1.jpg')

# Resmi göster
plt.imshow(img1)
plt.show()

# %% [markdown]
# # Yeni Bölüm

# %%
# Resmi oku
img2 = plt.imread('cat2.jpg')

# Resmi göster
plt.imshow(img2)
plt.show()

# %%
# Resmi oku
img3 = plt.imread('cat3.jpg')

# Resmi göster
plt.imshow(img3)
plt.show()

# %%
# Resmi oku
img4 = plt.imread('dog1.jpg')

# Resmi göster
plt.imshow(img4)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import imageio

# Load the image
img = imageio.imread('color_template.png')

# Display the original image
plt.imshow(img)
plt.title('Original Image')
plt.show()

# Updated transformation matrix from RGB to YIQ using the provided values
RGB_TO_YIQ = np.array([
    [0.2126, 0.7152, 0.0722],
    [-0.09991, -0.33609, 0.436],
    [0.615, -0.55861, -0.05639]
])

# Updated transformation matrix from YIQ to RGB using the provided values
YIQ_TO_RGB = np.array([
    [1, 0, 1.28033],
    [1, -0.21482, -0.38059],
    [1, 2.12798, 0]
])

# Apply the RGB to YIQ transformation
yiq_img = np.zeros_like(img, dtype=float)
for i in range(img.shape[0]):
    for j in range(img.shape[1]):
        yiq_img[i, j, :] = np.dot(RGB_TO_YIQ, img[i, j, :]/255.0)

# Display the YIQ image
plt.imshow(yiq_img)
plt.title('YIQ Image')
plt.show()

# Apply the YIQ to RGB transformation
rgb_converted_img = np.zeros_like(img)
for i in range(yiq_img.shape[0]):
    for j in range(yiq_img.shape[1]):
        rgb_converted_img[i, j, :] = np.clip(np.dot(YIQ_TO_RGB, yiq_img[i, j, :]), 0, 1) * 255

rgb_converted_img = rgb_converted_img.astype(np.uint8)

# Display the converted image
plt.imshow(rgb_converted_img)
plt.title('RGB Converted Image')
plt.show()
# Out:
# <ipython-input-8-7382bfbb9940>:6: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img = imageio.imread('color_template.png')
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# Vertical Flip
img_vertical_flip = np.flipud(img4)

# Horizontal Flip
img_horizontal_flip = np.fliplr(img4)

# Rotate Left by 90 degrees
img_rotate_left = np.rot90(img4, k=1, axes=(0, 1))

# Rotate Right by 90 degrees
img_rotate_right = np.rot90(img4, k=3, axes=(0, 1))

# Resize to Half
img_resized = transform.rescale(img4, 0.5, preserve_range=False, multichannel=True)

# Display input and output images
plt.figure(figsize=(10, 10))

plt.subplot(3, 3, 1)
plt.imshow(img4)
plt.title('Original Image')

plt.subplot(3, 3, 2)
plt.imshow(img_vertical_flip)
plt.title('Vertical Flip')

plt.subplot(3, 3, 3)
plt.imshow(img_horizontal_flip)
plt.title('Horizontal Flip')

plt.subplot(3, 3, 4)
plt.imshow(img_rotate_left)
plt.title('Rotate Left')

plt.subplot(3, 3, 5)
plt.imshow(img_rotate_right)
plt.title('Rotate Right')

plt.subplot(3, 3, 6)
plt.imshow(img_resized)
plt.title('Resized')

plt.show()
# Out:
# <ipython-input-15-33f8793fc346>:14: FutureWarning: `multichannel` is a deprecated argument name for `rescale`. It will be removed in version 1.0. Please use `channel_axis` instead.
#   img_resized = transform.rescale(img4, 0.5, preserve_range=False, multichannel=True)

# %%
# Vertical Flip
img_vertical_flip = np.flipud(img1)

# Horizontal Flip
img_horizontal_flip = np.fliplr(img1)

# Rotate Left by 90 degrees
img_rotate_left = np.rot90(img1, k=1, axes=(0, 1))

# Rotate Right by 90 degrees
img_rotate_right = np.rot90(img1, k=3, axes=(0, 1))

# Resize to Half
img_resized = transform.rescale(img1, 0.5, preserve_range=False, multichannel=True)

# Display input and output images
plt.figure(figsize=(10, 10))

plt.subplot(3, 3, 1)
plt.imshow(img1)
plt.title('Original Image')

plt.subplot(3, 3, 2)
plt.imshow(img_vertical_flip)
plt.title('Vertical Flip')

plt.subplot(3, 3, 3)
plt.imshow(img_horizontal_flip)
plt.title('Horizontal Flip')

plt.subplot(3, 3, 4)
plt.imshow(img_rotate_left)
plt.title('Rotate Left')

plt.subplot(3, 3, 5)
plt.imshow(img_rotate_right)
plt.title('Rotate Right')

plt.subplot(3, 3, 6)
plt.imshow(img_resized)
plt.title('Resized')

plt.show()
# Out:
# <ipython-input-16-ed73706ea78b>:14: FutureWarning: `multichannel` is a deprecated argument name for `rescale`. It will be removed in version 1.0. Please use `channel_axis` instead.
#   img_resized = transform.rescale(img1, 0.5, preserve_range=False, multichannel=True)

# %%
# Vertical Flip
img_vertical_flip = np.flipud(img2)

# Horizontal Flip
img_horizontal_flip = np.fliplr(img2)

# Rotate Left by 90 degrees
img_rotate_left = np.rot90(img2, k=1, axes=(0, 1))

# Rotate Right by 90 degrees
img_rotate_right = np.rot90(img2, k=3, axes=(0, 1))

# Resize to Half
img_resized = transform.rescale(img2, 0.5, preserve_range=False, multichannel=True)

# Display input and output images
plt.figure(figsize=(10, 10))

plt.subplot(3, 3, 1)
plt.imshow(img2)
plt.title('Original Image')

plt.subplot(3, 3, 2)
plt.imshow(img_vertical_flip)
plt.title('Vertical Flip')

plt.subplot(3, 3, 3)
plt.imshow(img_horizontal_flip)
plt.title('Horizontal Flip')

plt.subplot(3, 3, 4)
plt.imshow(img_rotate_left)
plt.title('Rotate Left')

plt.subplot(3, 3, 5)
plt.imshow(img_rotate_right)
plt.title('Rotate Right')

plt.subplot(3, 3, 6)
plt.imshow(img_resized)
plt.title('Resized')

plt.show()
# Out:
# <ipython-input-17-81e32c6be07c>:14: FutureWarning: `multichannel` is a deprecated argument name for `rescale`. It will be removed in version 1.0. Please use `channel_axis` instead.
#   img_resized = transform.rescale(img2, 0.5, preserve_range=False, multichannel=True)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# Vertical Flip
img_vertical_flip = np.flipud(img3)

# Horizontal Flip
img_horizontal_flip = np.fliplr(img3)

# Rotate Left by 90 degrees
img_rotate_left = np.rot90(img3, k=1, axes=(0, 1))

# Rotate Right by 90 degrees
img_rotate_right = np.rot90(img3, k=3, axes=(0, 1))

# Resize to Half
img_resized = transform.rescale(img3, 0.5, preserve_range=False, multichannel=True)

# Display input and output images
plt.figure(figsize=(10, 10))

plt.subplot(3, 3, 1)
plt.imshow(img3)
plt.title('Original Image')

plt.subplot(3, 3, 2)
plt.imshow(img_vertical_flip)
plt.title('Vertical Flip')

plt.subplot(3, 3, 3)
plt.imshow(img_horizontal_flip)
plt.title('Horizontal Flip')

plt.subplot(3, 3, 4)
plt.imshow(img_rotate_left)
plt.title('Rotate Left')

plt.subplot(3, 3, 5)
plt.imshow(img_rotate_right)
plt.title('Rotate Right')

plt.subplot(3, 3, 6)
plt.imshow(img_resized)
plt.title('Resized')

plt.show()
# Out:
# <ipython-input-18-f75750c11a30>:14: FutureWarning: `multichannel` is a deprecated argument name for `rescale`. It will be removed in version 1.0. Please use `channel_axis` instead.
#   img_resized = transform.rescale(img3, 0.5, preserve_range=False, multichannel=True)
